# %% [markdown]
# # Limpieza, exploración y preparación de datos prueba PLANEA 2015
#
# ## Usado también como caso para la materia Programación para Analítica de Datos
#
# #### Mtra. Gisel Hernández Chávez
#
# ### Contenido
#
# 1. Cargar base de datos PLANEA 2015 y explorar información general. ESTE ARCHIVO CONTIENE FILAS QUE SE ADICIONARON AL ORIGINAL CSV CON PREPARATORIAS QUE NO HICIERON PLANEA O EMISORES DE CERTIFICADOS DE PREPARATORIA (REVALIDACIONES Y ACREDITACIONES), ASÍ COMO DE ESCUELAS CLASIFICADAS COMO EXTRANJERAS.
# 2. Procesar valores faltantes
#
#     2.1 Imputar localidades faltantes con nombre del municipio
#
#     2.2 Modificar ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO convirtiendo a booleano
#
#     2.3 Limpieza de columna EXTENSIÓN
#
# 3. Eliminar CCT duplicados con menor ind_gral
# 4. Imputar con 0 donde aparece 'S/R'
# 5. Guardar archivo de PLANEA 2015 limpio y sus tipos
# 6. Reporte EDA con pandas-profiling

# %% [markdown]
# ### Análisis de posibilidades de nuevas características (predictoras):
#
# + Los resultados de las prepas en la prueba PLANEA en 2015 por preparatoria se usarán para crear un indicador de desempeño "ind_integral" que será la suma de "ind-len" e "ind-mat". Estos son una suma ponderada:
#
#     ind_len = 0.25*esc_leng_I + 0.5*esc_leng_II + 0.75*esc_leng_III + 1*esc_leng_IV
#
#     ind_mat = 0.25*esc_mat_I + 0.5*esc_mat_II + 0.75*esc_mat_III + 1*esc_mat_IV
#
#     Esta nueva característica será del tipo razón y se probará en la regresión.
#
# + La clasificación de las prepas según su subsistema no se agregará porque ya se tiene una clasificación parecida [pública/privada]:
#     + ASOCIACIÓN CIVIL
#     + BACHILLERATO AUTÓNOMO
#     + CECYTE
#     + COBACH
#     + CONALEP
#     + DGECYTM
#     + DGETA
#     + DGETI
#     + EMSAD
#     + OTRAS FEDERALES
#     + PARTICULARES
#     + TELEBACHILLERATOS
# + La clasificación de las prepas según su sostenimiento no se agregará porque ya se tiene una clasificación parecida [pública/privada]:
#     + particulares
#     + federal
#     + autónoma
#     + estatal
# + La clasificación de las localidades de las prepas en cuanto al grado de marginación se agregará como característica categórica. Se convertirá en ordinal con valores del 1 al 5
#
#     En PLANEA se divide en:
#     + MUY ALTO, ALTO, MEDIO, BAJO y MUY BAJO

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import pandas_profiling
#from pandas_profiling import ProfileReport

# %%
# Para obtener múltiples salidas de una celda
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 1. Cargar base de datos con PLANEA y explorar información general
#
# + Se especifican datos de subsistema, sostenimiento y grado de marginación, además de los resultados de la prueba y algunos resultados del análisis exploratorio

# %%
#tray = "C:\\Users\\ghernand\\Documents\\Desercion\\data\\"
planea = pd.read_csv("NAC_ESCUELAS_PMS2015.csv", low_memory=False)
planea
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12844/90156373.py in <module>
#       1 #tray = "C:\\Users\\ghernand\\Documents\\Desercion\\data\\"
# ----> 2 planea = pd.read_csv("NAC_ESCUELAS_PMS2015.csv", low_memory=False)
#       3 planea
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# d:\Programs\Code\anaconda3\envs\DeepEnv\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NAC_ESCUELAS_PMS2015.csv'

# %%
# Respaldo
planea_bk = planea.copy()

# %%
planea.head(2)  # dos primeras filas
planea.tail(2)  # dos últimas filas
# Out:
#    CLAVE DE LA ENTIDAD                         NOMBRE_ESCUELA CLAVE_ESCUELA  \
# 0                   12  UNIDAD ACADÉMICA: PREPARATORIA NO. 36    12UBH0009Z
# 1                    1      CBTA NO. 40 JOSÉ GUADALUPE POSADA    01DTA0040J
#
#       TURNO EXTENSIÓN         ENTIDAD     MUNICIPIO         LOCALIDAD  \
# 0  MATUTINO       NaN        GUERRERO  EDUARDO NERI  ZUMPANGO DEL RIO
# 1  MATUTINO       NaN  AGUASCALIENTES      ASIENTOS      VILLA JUAREZ
#
#               SUBSISTEMA GRADO_MARGINACIÓN_LOCALIDAD_CCT  ...  \
# 0  BACHILLERATO AUTÓNOMO                            ALTO  ...
# 1                  DGETA                            BAJO  ...
#
#   pa_ss_mar_mat_II  pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  \
# 0             22.6                9.5               3.2     27.6     6.4
# 1               30               12.8               7.1     44.5    16.9
#
#    ind-compuesto  ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 0           34.0     3.8         47.60        35.775    83.375
# 1           61.4    16.5         56.55        43.850   100.400
#
# [2 rows x 48 columns]
#        CLAVE DE LA ENTIDAD                                     NOMBRE_ESCUELA  \
# 14652                   33                  SISTEMA EDUCATIVO NACIONAL *10343
# 14653                   33  ESCUELA REGIONAL DE EDUCACION MEDIA SUPERIOR D...
#
#       CLAVE_ESCUELA     TURNO EXTENSIÓN     ENTIDAD MUNICIPIO LOCALIDAD  \
# 14652    11DEX0001G  MATUTINO       NaN  GUANAJUATO    CELAYA       NaN
# 14653    14UBH0066P  MATUTINO       NaN     JALISCO   OCOTLAN       NaN
#
#       SUBSISTEMA GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 14652    PÚBLICO                            BAJO  ...                0
# 14653    PÚBLICO                        MUY BAJO  ...                0
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 14652                  0                 0      0.0     0.0            0.0
# 14653                  0                 0      0.0     0.0            0.0
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 14652     0.0           0.0           0.0       0.0
# 14653     0.0           0.0           0.0       0.0
#
# [2 rows x 48 columns]

# %%
# Tipo de cada columna
planea.dtypes
# Out:
# CLAVE DE LA ENTIDAD                                        int64
# NOMBRE_ESCUELA                                            object
# CLAVE_ESCUELA                                             object
# TURNO                                                     object
# EXTENSIÓN                                                 object
# ENTIDAD                                                   object
# MUNICIPIO                                                 object
# LOCALIDAD                                                 object
# SUBSISTEMA                                                object
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                           object
# SOSTENIMIENTO                                             object
# ALUMNOS_PROGRAMADOS                                        int64
# ALUMNOS_EVALUADOS                                          int64
# PORCENTAJE_ ALUMNOS_EVALUADOS                            float64
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                      object
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE      int64
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT            int64
# esc_leng_I                                               float64
# esc_leng_II                                              float64
# esc_leng_III                                             float64
# esc_leng_IV                                              float64
# ent_ss_mar_len_I                                          object
# ent_ss_mar_len_II                                         object
# ent_ss_mar_len_III                                        object
# ent_ss_mar_len_IV                                         object
# pa_ss_mar_len_I                                           object
# pa_ss_mar_len_II                                          object
# pa_ss_mar_len_III                                         object
# pa_ss_mar_len_IV                                          object
# esc_mat_I                                                float64
# esc_mat_II                                               float64
# esc_mat_III                                              float64
# esc_mat_IV                                               float64
# ent_ss_mar_mat_I                                          object
# ent_ss_mar_mat_II                                         object
# ent_ss_mar_mat_III                                        object
# ent_ss_mar_mat_IV                                         object
# pa_ss_mar_mat_I                                           object
# pa_ss_mar_mat_II                                          object
# pa_ss_mar_mat_III                                         object
# pa_ss_mar_mat_IV                                          object
# ind_len                                                  float64
# ind_mat                                                  float64
# ind-compuesto                                            float64
# ind_IV                                                   float64
# ind_gral_len                                             float64
# ind_gral_mat                                             float64
# ind_gral                                                 float64
# dtype: object

# %%
# (filas, columnas)
planea.shape
# Out:
# (14654, 48)

# %%
# Conteo de no nulos y tipos de cada columna
planea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14654 entries, 0 to 14653
# Data columns (total 48 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   CLAVE DE LA ENTIDAD                                    14654 non-null  int64
#  1   NOMBRE_ESCUELA                                         14654 non-null  object
#  2   CLAVE_ESCUELA                                          14654 non-null  object
#  3   TURNO                                                  14654 non-null  object
#  4   EXTENSIÓN                                              333 non-null    object
#  5   ENTIDAD                                                14654 non-null  object
#  6   MUNICIPIO                                              14654 non-null  object
#  7   LOCALIDAD                                              14513 non-null  object
#  8   SUBSISTEMA                                             14654 non-null  object
#  9   GRADO_MARGINACIÓN_LOCALIDAD_CCT                        14654 non-null  object
#  10  SOSTENIMIENTO                                          14654 non-null  object
#  11  ALUMNOS_PROGRAMADOS                                    14654 non-null  int64
#  12  ALUMNOS_EVALUADOS                                      14654 non-null  int64
#  13  PORCENTAJE_ ALUMNOS_EVALUADOS                          14654 non-null  float64
#  14  ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                   14547 non-null  object
#  15  ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE  14654 non-null  int64
#  16  ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT        14654 non-null  int64
#  17  esc_leng_I                                             14654 non-null  float64
#  18  esc_leng_II                                            14654 non-null  float64
#  19  esc_leng_III                                           14654 non-null  float64
#  20  esc_leng_IV                                            14654 non-null  float64
#  21  ent_ss_mar_len_I                                       14654 non-null  object
#  22  ent_ss_mar_len_II                                      14654 non-null  object
#  23  ent_ss_mar_len_III                                     14654 non-null  object
#  24  ent_ss_mar_len_IV                                      14654 non-null  object
#  25  pa_ss_mar_len_I                                        14654 non-null  object
#  26  pa_ss_mar_len_II                                       14654 non-null  object
#  27  pa_ss_mar_len_III                                      14654 non-null  object
#  28  pa_ss_mar_len_IV                                       14654 non-null  object
#  29  esc_mat_I                                              14654 non-null  float64
#  30  esc_mat_II                                             14654 non-null  float64
#  31  esc_mat_III                                            14654 non-null  float64
#  32  esc_mat_IV                                             14654 non-null  float64
#  33  ent_ss_mar_mat_I                                       14654 non-null  object
#  34  ent_ss_mar_mat_II                                      14654 non-null  object
#  35  ent_ss_mar_mat_III                                     14654 non-null  object
#  36  ent_ss_mar_mat_IV                                      14654 non-null  object
#  37  pa_ss_mar_mat_I                                        14654 non-null  object
#  38  pa_ss_mar_mat_II                                       14654 non-null  object
#  39  pa_ss_mar_mat_III                                      14654 non-null  object
#  40  pa_ss_mar_mat_IV                                       14654 non-null  object
#  41  ind_len                                                14654 non-null  float64
#  42  ind_mat                                                14654 non-null  float64
#  43  ind-compuesto                                          14654 non-null  float64
#  44  ind_IV                                                 14654 non-null  float64
#  45  ind_gral_len                                           14654 non-null  float64
#  46  ind_gral_mat                                           14654 non-null  float64
#  47  ind_gral                                               14654 non-null  float64
# dtypes: float64(16), int64(5), object(27)
# memory usage: 5.4+ MB

# %%
# Lista de columnas
planea.columns
# Out:
# Index(['CLAVE DE LA ENTIDAD', 'NOMBRE_ESCUELA', 'CLAVE_ESCUELA', 'TURNO',
#        'EXTENSIÓN', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'SUBSISTEMA',
#        'GRADO_MARGINACIÓN_LOCALIDAD_CCT', 'SOSTENIMIENTO',
#        'ALUMNOS_PROGRAMADOS', 'ALUMNOS_EVALUADOS',
#        'PORCENTAJE_ ALUMNOS_EVALUADOS', 'ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO',
#        'ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE',
#        'ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT', 'esc_leng_I',
#        'esc_leng_II', 'esc_leng_III', 'esc_leng_IV', 'ent_ss_mar_len_I',
#        'ent_ss_mar_len_II', 'ent_ss_mar_len_III', 'ent_ss_mar_len_IV',
#        'pa_ss_mar_len_I', 'pa_ss_mar_len_II', 'pa_ss_mar_len_III',
#        'pa_ss_mar_len_IV', 'esc_mat_I', 'esc_mat_II', 'esc_mat_III',
#        'esc_mat_IV', 'ent_ss_mar_mat_I', 'ent_ss_mar_mat_II',
#        'ent_ss_mar_mat_III', 'ent_ss_mar_mat_IV', 'pa_ss_mar_mat_I',
#        'pa_ss_mar_mat_II', 'pa_ss_mar_mat_III', 'pa_ss_mar_mat_IV', 'ind_len',
#        'ind_mat', 'ind-compuesto', 'ind_IV', 'ind_gral_len', 'ind_gral_mat',
#        'ind_gral'],
#       dtype='object')

# %%
f'Total de escuelas evaluadas + adicionadas: {planea.shape[0]}  Cantidad de columnas de datos: {planea.shape[1]}'
# Out:
# 'Total de escuelas evaluadas + adicionadas: 14654  Cantidad de columnas de datos: 48'

# %%
# Localiza una fila dado su índice
planea.iloc[28]
# Out:
# CLAVE DE LA ENTIDAD                                                        1
# NOMBRE_ESCUELA                                           CEMSAD LOS NEGRITOS
# CLAVE_ESCUELA                                                     01EMS0015Z
# TURNO                                                             VESPERTINO
# EXTENSIÓN                                                                NaN
# ENTIDAD                                                       AGUASCALIENTES
# MUNICIPIO                                                     AGUASCALIENTES
# LOCALIDAD                                                       LOS NEGRITOS
# SUBSISTEMA                                                             EMSAD
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                                         BAJO
# SOSTENIMIENTO                                                        ESTATAL
# ALUMNOS_PROGRAMADOS                                                       31
# ALUMNOS_EVALUADOS                                                         28
# PORCENTAJE_ ALUMNOS_EVALUADOS                                          90.32
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE                     27
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT                           28
# esc_leng_I                                                              88.9
# esc_leng_II                                                              7.4
# esc_leng_III                                                             3.7
# esc_leng_IV                                                              0.0
# ent_ss_mar_len_I                                                        61.6
# ent_ss_mar_len_II                                                       19.2
# ent_ss_mar_len_III                                                        16
# ent_ss_mar_len_IV                                                        3.2
# pa_ss_mar_len_I                                                         46.2
# pa_ss_mar_len_II                                                        23.1
# pa_ss_mar_len_III                                                       21.8
# pa_ss_mar_len_IV                                                           9
# esc_mat_I                                                               92.9
# esc_mat_II                                                               7.1
# esc_mat_III                                                              0.0
# esc_mat_IV                                                               0.0
# ent_ss_mar_mat_I                                                        69.5
# ent_ss_mar_mat_II                                                       25.2
# ent_ss_mar_mat_III                                                       4.6
# ent_ss_mar_mat_IV                                                        0.7
# pa_ss_mar_mat_I                                                           57
# pa_ss_mar_mat_II                                                        27.8
# pa_ss_mar_mat_III                                                       10.3
# pa_ss_mar_mat_IV                                                         4.9
# ind_len                                                                  3.7
# ind_mat                                                                  0.0
# ind-compuesto                                                            3.7
# ind_IV                                                                   0.0
# ind_gral_len                                                            28.7
# ind_gral_mat                                                          26.775
# ind_gral                                                              55.475
# Name: 28, dtype: object

# %%
# Localiza un conjunto de filas usando slicing
planea.iloc[2:10:2]
# Out:
#    CLAVE DE LA ENTIDAD                         NOMBRE_ESCUELA CLAVE_ESCUELA  \
# 2                   12  UNIDAD ACADÉMICA: PREPARATORIA NO. 36    12UBH0009Z
# 4                    1            TELEBACHILLERATO VALLADOLID    01ETH0016B
# 6                   15                CENTRO MARIA MONTESSORI    15PCT0685F
# 8                    1            CEMSAD STA. MARÍA DE LA PAZ    01EMS0011C
#
#         TURNO EXTENSIÓN         ENTIDAD     MUNICIPIO              LOCALIDAD  \
# 2  VESPERTINO       NaN        GUERRERO  EDUARDO NERI       ZUMPANGO DEL RIO
# 4    MATUTINO       NaN  AGUASCALIENTES   JESUS MARIA             VALLADOLID
# 6    MATUTINO       NaN          MÉXICO      ZUMPANGO     ZUMPANGO DE OCAMPO
# 8  VESPERTINO       NaN  AGUASCALIENTES         COSIO  SANTA MARIA DE LA PAZ
#
#               SUBSISTEMA GRADO_MARGINACIÓN_LOCALIDAD_CCT  ...  \
# 2  BACHILLERATO AUTÓNOMO                            ALTO  ...
# 4      TELEBACHILLERATOS                        MUY BAJO  ...
# 6           PARTICULARES                            BAJO  ...
# 8                  EMSAD                           MEDIO  ...
#
#   pa_ss_mar_mat_II  pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  \
# 2             22.6                9.5               3.2      7.2     3.5
# 4             26.9                6.1               1.2     30.0     5.0
# 6             30.1               14.2               7.5     20.0    18.2
# 8               27               10.8               7.7      0.0     0.0
#
#    ind-compuesto  ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 2           10.7     1.8          33.1        29.825    62.925
# 4           35.0     5.0          45.0        36.250    81.250
# 6           38.2    19.1          42.5        38.650    81.150
# 8            0.0     0.0          30.0        27.500    57.500
#
# [4 rows x 48 columns]

# %%
# Ejemplo de creación de un DataFrame filtrando por una condición

matutino = planea.loc[planea['TURNO'] == 'MATUTINO']
matutino.drop(['TURNO'],axis=1,inplace=True)
# matutino = matutino.drop(['TURNO'],axis=1)
matutino.shape
matutino[['CLAVE DE LA ENTIDAD', 'NOMBRE_ESCUELA', 'CLAVE_ESCUELA', 
       'EXTENSIÓN', 'ENTIDAD', 'MUNICIPIO']]
# Out:
# C:\Users\ghernand\AppData\Local\Temp\ipykernel_5108\4239899522.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matutino.drop(['TURNO'],axis=1,inplace=True)
# (10941, 47)
#        CLAVE DE LA ENTIDAD                                     NOMBRE_ESCUELA  \
# 0                       12              UNIDAD ACADÉMICA: PREPARATORIA NO. 36
# 1                        1                  CBTA NO. 40 JOSÉ GUADALUPE POSADA
# 3                       12  CENTRO DE ESTUDIOS DEL BACHILLERATO GENERAL JE...
# 4                        1                        TELEBACHILLERATO VALLADOLID
# 5                       15  BACHILLERATO TECNOLOGICO DEL INSTITUTO EDUCATI...
# ...                    ...                                                ...
# 14649                   33                  SISTEMA EDUCATIVO NACIONAL *10344
# 14650                   33          INSTITUTO SONORENSE DE EDUCACION * 060911
# 14651                   33                             COLEGIO CALMECAC *9683
# 14652                   33                  SISTEMA EDUCATIVO NACIONAL *10343
# 14653                   33  ESCUELA REGIONAL DE EDUCACION MEDIA SUPERIOR D...
#
#       CLAVE_ESCUELA EXTENSIÓN         ENTIDAD        MUNICIPIO
# 0        12UBH0009Z       NaN        GUERRERO     EDUARDO NERI
# 1        01DTA0040J       NaN  AGUASCALIENTES         ASIENTOS
# 3        12PBH0012B       NaN        GUERRERO     EDUARDO NERI
# 4        01ETH0016B       NaN  AGUASCALIENTES      JESUS MARIA
# 5        15PCT0813K       NaN          MÉXICO         ZUMPANGO
# ...             ...       ...             ...              ...
# 14649    13DEX0001E       NaN         HIDALGO  PACHUCA DE SOTO
# 14650    26EEX0001H       NaN          SONORA       HERMOSILLO
# 14651    14PBJ0010Q       NaN         JALISCO          ZAPOPAN
# 14652    11DEX0001G       NaN      GUANAJUATO           CELAYA
# 14653    14UBH0066P       NaN         JALISCO          OCOTLAN
#
# [10941 rows x 6 columns]

# %% [markdown]
# ### Observaciones:
#
# + Las columnas 'ind_len', 'ind_mat', 'ind-compuesto', 'ind_IV', 'ind_gral_len', 'ind_gral_mat','ind_gral'  son nuevas características creadas con los fines de la predicción.
# + El significado de las columnas se detalla a continuación:

# %% [markdown]
# ## 2. Valores faltantes

# %%
planea.isnull().sum()
# Out:
# CLAVE DE LA ENTIDAD                                          0
# NOMBRE_ESCUELA                                               0
# CLAVE_ESCUELA                                                0
# TURNO                                                        0
# EXTENSIÓN                                                14321
# ENTIDAD                                                      0
# MUNICIPIO                                                    0
# LOCALIDAD                                                  141
# SUBSISTEMA                                                   0
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                              0
# SOSTENIMIENTO                                                0
# ALUMNOS_PROGRAMADOS                                          0
# ALUMNOS_EVALUADOS                                            0
# PORCENTAJE_ ALUMNOS_EVALUADOS                                0
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                       107
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE        0
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT              0
# esc_leng_I                                                   0
# esc_leng_II                                                  0
# esc_leng_III                                                 0
# esc_leng_IV                                                  0
# ent_ss_mar_len_I                                             0
# ent_ss_mar_len_II                                            0
# ent_ss_mar_len_III                                           0
# ent_ss_mar_len_IV                                            0
# pa_ss_mar_len_I                                              0
# pa_ss_mar_len_II                                             0
# pa_ss_mar_len_III                                            0
# pa_ss_mar_len_IV                                             0
# esc_mat_I                                                    0
# esc_mat_II                                                   0
# esc_mat_III                                                  0
# esc_mat_IV                                                   0
# ent_ss_mar_mat_I                                             0
# ent_ss_mar_mat_II                                            0
# ent_ss_mar_mat_III                                           0
# ent_ss_mar_mat_IV                                            0
# pa_ss_mar_mat_I                                              0
# pa_ss_mar_mat_II                                             0
# pa_ss_mar_mat_III                                            0
# pa_ss_mar_mat_IV                                             0
# ind_len                                                      0
# ind_mat                                                      0
# ind-compuesto                                                0
# ind_IV                                                       0
# ind_gral_len                                                 0
# ind_gral_mat                                                 0
# ind_gral                                                     0
# dtype: int64

# %% [markdown]
# ## Hallazgos:
#
# + La mayoría de las escuelas no tiene extensiones. Explorar la columna para determinar si se elimina o se imputan los nulos.
# + Revisar filas sin localidad e imputar con Municipio o buscar una por una en internet
# + Revisar la única fila que no tiene ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO

# %% [markdown]
# ### 2.1 Imputar localidades faltantes con nombre del municipio

# %%
# Muestra una vista de las filas con valor nulo en LOCALIDAD
planea.loc[planea.LOCALIDAD.isnull()]
# Out:
#        CLAVE DE LA ENTIDAD                                     NOMBRE_ESCUELA  \
# 6613                    16  CENTRO DE BACHILLERATO TECNOLOGICO AGROPECUARI...
# 6614                    16                     COLEGIO DE BACHILLERES MORELIA
# 6615                    16                      COLEGIO DE BACHILLERES ZAMORA
# 6616                    16              CECYTE EMSAD 51 EL PUERTO DE JUNGAPEO
# 6618                    16             COLEGIO DE BACHILLERES LAZARO CARDENAS
# ...                    ...                                                ...
# 14649                   33                  SISTEMA EDUCATIVO NACIONAL *10344
# 14650                   33          INSTITUTO SONORENSE DE EDUCACION * 060911
# 14651                   33                             COLEGIO CALMECAC *9683
# 14652                   33                  SISTEMA EDUCATIVO NACIONAL *10343
# 14653                   33  ESCUELA REGIONAL DE EDUCACION MEDIA SUPERIOR D...
#
#       CLAVE_ESCUELA     TURNO EXTENSIÓN     ENTIDAD        MUNICIPIO  \
# 6613     16DTA0290R  MATUTINO       NaN   MICHOACAN           ZAMORA
# 6614     16ECB5005V  MATUTINO       NaN   MICHOACAN          MORELIA
# 6615     16ECB5002Y  MATUTINO       NaN   MICHOACAN           ZAMORA
# 6616     16EMS0051F  MATUTINO       NaN   MICHOACAN         JUNGAPEO
# 6618     16ECB5007T  MATUTINO       NaN   MICHOACAN  LAZARO CARDENAS
# ...             ...       ...       ...         ...              ...
# 14649    13DEX0001E  MATUTINO       NaN     HIDALGO  PACHUCA DE SOTO
# 14650    26EEX0001H  MATUTINO       NaN      SONORA       HERMOSILLO
# 14651    14PBJ0010Q  MATUTINO       NaN     JALISCO          ZAPOPAN
# 14652    11DEX0001G  MATUTINO       NaN  GUANAJUATO           CELAYA
# 14653    14UBH0066P  MATUTINO       NaN     JALISCO          OCOTLAN
#
#       LOCALIDAD    SUBSISTEMA GRADO_MARGINACIÓN_LOCALIDAD_CCT  ...  \
# 6613        NaN         DGETA                            ALTO  ...
# 6614        NaN        COBACH                        MUY BAJO  ...
# 6615        NaN        COBACH                            BAJO  ...
# 6616        NaN         EMSAD                           MEDIO  ...
# 6618        NaN        COBACH                        MUY BAJO  ...
# ...         ...           ...                             ...  ...
# 14649       NaN       PÚBLICO                            BAJO  ...
# 14650       NaN       PÚBLICO                        MUY BAJO  ...
# 14651       NaN  PARTICULARES                        MUY BAJO  ...
# 14652       NaN       PÚBLICO                            BAJO  ...
# 14653       NaN       PÚBLICO                        MUY BAJO  ...
#
#       pa_ss_mar_mat_II  pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  \
# 6613              26.9               11.4               6.3    100.0   100.0
# 6614              32.6               13.1               6.7     40.0    20.0
# 6615              28.4               11.2               5.1      9.1    10.0
# 6616                27               10.8               7.7     50.0     0.0
# 6618              32.6               13.1               6.7     20.0     0.0
# ...                ...                ...               ...      ...     ...
# 14649                0                  0                 0      0.0     0.0
# 14650                0                  0                 0      0.0     0.0
# 14651                0                  0                 0      0.0     0.0
# 14652                0                  0                 0      0.0     0.0
# 14653                0                  0                 0      0.0     0.0
#
#        ind-compuesto  ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 6613           200.0   200.0       100.000         100.0   200.000
# 6614            60.0    20.0        50.000          45.0    95.000
# 6615            19.1    19.1        36.375          42.5    78.875
# 6616            50.0     0.0        50.000          25.0    75.000
# 6618            20.0     0.0        45.000          30.0    75.000
# ...              ...     ...           ...           ...       ...
# 14649            0.0     0.0         0.000           0.0     0.000
# 14650            0.0     0.0         0.000           0.0     0.000
# 14651            0.0     0.0         0.000           0.0     0.000
# 14652            0.0     0.0         0.000           0.0     0.000
# 14653            0.0     0.0         0.000           0.0     0.000
#
# [141 rows x 48 columns]

# %%
# Localizar y reasignar valor en el mismo paso
planea.loc[planea.LOCALIDAD.isnull(),['LOCALIDAD']] = planea.MUNICIPIO  # Se imputa con valor de MUNICIPIO
planea.loc[planea.LOCALIDAD.isnull()]
# Out:
# Empty DataFrame
# Columns: [CLAVE DE LA ENTIDAD, NOMBRE_ESCUELA, CLAVE_ESCUELA, TURNO, EXTENSIÓN, ENTIDAD, MUNICIPIO, LOCALIDAD, SUBSISTEMA, GRADO_MARGINACIÓN_LOCALIDAD_CCT, SOSTENIMIENTO, ALUMNOS_PROGRAMADOS, ALUMNOS_EVALUADOS, PORCENTAJE_ ALUMNOS_EVALUADOS, ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE, ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT, esc_leng_I, esc_leng_II, esc_leng_III, esc_leng_IV, ent_ss_mar_len_I, ent_ss_mar_len_II, ent_ss_mar_len_III, ent_ss_mar_len_IV, pa_ss_mar_len_I, pa_ss_mar_len_II, pa_ss_mar_len_III, pa_ss_mar_len_IV, esc_mat_I, esc_mat_II, esc_mat_III, esc_mat_IV, ent_ss_mar_mat_I, ent_ss_mar_mat_II, ent_ss_mar_mat_III, ent_ss_mar_mat_IV, pa_ss_mar_mat_I, pa_ss_mar_mat_II, pa_ss_mar_mat_III, pa_ss_mar_mat_IV, ind_len, ind_mat, ind-compuesto, ind_IV, ind_gral_len, ind_gral_mat, ind_gral]
# Index: []
#
# [0 rows x 48 columns]

# %%
# Vista de filas donde MUNICIPIO = LOCALIDAD
# Localizar y mostrar en un solo paso
planea.loc[planea.MUNICIPIO == planea.LOCALIDAD,['MUNICIPIO','LOCALIDAD']]
# Out:
#                        MUNICIPIO                  LOCALIDAD
# 9                       ZUMPANGO                   ZUMPANGO
# 12            SAN JOSE DE GRACIA         SAN JOSE DE GRACIA
# 14     SAN FRANCISCO DE LOS ROMO  SAN FRANCISCO DE LOS ROMO
# 17               RINCON DE ROMOS            RINCON DE ROMOS
# 18               RINCON DE ROMOS            RINCON DE ROMOS
# ...                          ...                        ...
# 14649            PACHUCA DE SOTO            PACHUCA DE SOTO
# 14650                 HERMOSILLO                 HERMOSILLO
# 14651                    ZAPOPAN                    ZAPOPAN
# 14652                     CELAYA                     CELAYA
# 14653                    OCOTLAN                    OCOTLAN
#
# [6851 rows x 2 columns]

# %% [markdown]
# ### 2.2 Modificar ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO convirtiendo a booleano

# %%
# Vista de aquellos donde ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO es null
planea.loc[planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.isnull(), ['NOMBRE_ESCUELA','MUNICIPIO','LOCALIDAD',
                                                                  'ALUMNOS_PROGRAMADOS','ALUMNOS_EVALUADOS',
                                                                  'ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO']]
# Out:
#                                           NOMBRE_ESCUELA        MUNICIPIO  \
# 10433  INSTITUTO TECNOLÓGICO Y DE ESTUDIOS SUPERIORES...        FRESNILLO
# 14548                  RESOLUCION DE EQUIVALENCIA *10102       EXTRANJERO
# 14549                  RESOLUCION DE REVALIDACION *10101       EXTRANJERO
# 14550                   RESOLUCION DE REVALIDACION *9635       EXTRANJERO
# 14551                  SISTEMA EDUCATIVO NACIONAL *10336      GUADALAJARA
# ...                                                  ...              ...
# 14649                  SISTEMA EDUCATIVO NACIONAL *10344  PACHUCA DE SOTO
# 14650          INSTITUTO SONORENSE DE EDUCACION * 060911       HERMOSILLO
# 14651                             COLEGIO CALMECAC *9683          ZAPOPAN
# 14652                  SISTEMA EDUCATIVO NACIONAL *10343           CELAYA
# 14653  ESCUELA REGIONAL DE EDUCACION MEDIA SUPERIOR D...          OCOTLAN
#
#              LOCALIDAD  ALUMNOS_PROGRAMADOS  ALUMNOS_EVALUADOS  \
# 10433        FRESNILLO                   19                 18
# 14548       EXTRANJERO                    0                  0
# 14549       EXTRANJERO                    0                  0
# 14550       EXTRANJERO                    0                  0
# 14551      GUADALAJARA                    0                  0
# ...                ...                  ...                ...
# 14649  PACHUCA DE SOTO                    0                  0
# 14650       HERMOSILLO                    0                  0
# 14651          ZAPOPAN                    0                  0
# 14652           CELAYA                    0                  0
# 14653          OCOTLAN                    0                  0
#
#       ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO
# 10433                                  NaN
# 14548                                  NaN
# 14549                                  NaN
# 14550                                  NaN
# 14551                                  NaN
# ...                                    ...
# 14649                                  NaN
# 14650                                  NaN
# 14651                                  NaN
# 14652                                  NaN
# 14653                                  NaN
#
# [107 rows x 6 columns]

# %%
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.unique()
# Out:
# array([' ', 'SÍ', nan], dtype=object)

# %%
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.value_counts(dropna=False)
# Out:
#        12936
# SÍ      1611
# NaN      107
# Name: ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, dtype: int64

# %%
# Para obtener las proporciones
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.value_counts(dropna=False,normalize=True)
# Out:
#        0.882762
# SÍ     0.109936
# NaN    0.007302
# Name: ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, dtype: float64

# %%
# Vista de aquellos donde ALUMNOS_EVALUADOS_MENOR_80_PORCIENT es ' ' (cadena vacía)
planea.loc[planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO ==' ', ['NOMBRE_ESCUELA','MUNICIPIO','LOCALIDAD',
                                                                  'ALUMNOS_PROGRAMADOS','ALUMNOS_EVALUADOS',
                                                                  'ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO']]
# Out:
#                                           NOMBRE_ESCUELA     MUNICIPIO  \
# 0                  UNIDAD ACADÉMICA: PREPARATORIA NO. 36  EDUARDO NERI
# 1                      CBTA NO. 40 JOSÉ GUADALUPE POSADA      ASIENTOS
# 2                  UNIDAD ACADÉMICA: PREPARATORIA NO. 36  EDUARDO NERI
# 3      CENTRO DE ESTUDIOS DEL BACHILLERATO GENERAL JE...  EDUARDO NERI
# 4                            TELEBACHILLERATO VALLADOLID   JESUS MARIA
# ...                                                  ...           ...
# 14542              COLEGIO DE BACHILLERES PLANTEL APOZOL        APOZOL
# 14544                                 JAIME TORRES BODET       MORELIA
# 14545                              ESCUELA DE ENFERMERIA       MORELIA
# 14546                                    EMSAD APIZOLAYA       MAZAPIL
# 14547              EMSAD "RAMÓN LÓPEZ VELARDE" (TORIBIO)        CALERA
#
#                             LOCALIDAD  ALUMNOS_PROGRAMADOS  ALUMNOS_EVALUADOS  \
# 0                    ZUMPANGO DEL RIO                  122                112
# 1                        VILLA JUAREZ                  224                218
# 2                    ZUMPANGO DEL RIO                   63                 57
# 3                    ZUMPANGO DEL RIO                    5                  5
# 4                          VALLADOLID                   20                 20
# ...                               ...                  ...                ...
# 14542                          APOZOL                   40                 39
# 14544                         MORELIA                    9                  9
# 14545                         MORELIA                   29                 26
# 14546                       APIZOLAYA                    8                  8
# 14547  "RAMON LOPEZ VELARDE" (TORIBIO                   27                 24
#
#       ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO
# 0
# 1
# 2
# 3
# 4
# ...                                    ...
# 14542
# 14544
# 14545
# 14546
# 14547
#
# [12936 rows x 6 columns]

# %%
# Usar dropna=False para mostrar conteo de nulos
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.value_counts(dropna=False)
# Out:
#        12936
# SÍ      1611
# NaN      107
# Name: ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, dtype: int64

# %%
#pd.value_counts?

# %%
# Aquí se hace la imputación
d = {'SÍ': True, ' ': False, np.nan: False}

planea['ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO'] = planea['ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO'].map(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12844/3171252738.py in <module>
#       1 # Aquí se hace la imputación
# ----> 2 d = {'SÍ': True, ' ': False, np.nan: False}
#       3
#       4 planea['ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO'] = planea['ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO'].map(d)
#
# NameError: name 'np' is not defined

# %%
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14649      NaN
# 14650      NaN
# 14651      NaN
# 14652      NaN
# 14653      NaN
# Name: ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, Length: 14654, dtype: object

# %%
# Verificar que los que evaluaron menos del 80% de los programados sean
#los que tienen True en ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO
porc_80 = planea['ALUMNOS_EVALUADOS'] /planea['ALUMNOS_PROGRAMADOS']
planea.loc[ (porc_80 *100 < 80) & (planea['ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO'] != True ),['NOMBRE_ESCUELA',
                               'ALUMNOS_PROGRAMADOS','ALUMNOS_EVALUADOS',
                               'ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO' ]]
# Out:
# Empty DataFrame
# Columns: [NOMBRE_ESCUELA, ALUMNOS_PROGRAMADOS, ALUMNOS_EVALUADOS, ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO]
# Index: []

# %%
# Usar dropna=False para mostrar conteo de nulos
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.value_counts(dropna=False)
# Out:
# False    12936
# True      1611
# NaN        107
# Name: ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, dtype: int64

# %%
planea.loc[planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.isnull(), ['ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO']] = False

# %%
planea.loc[planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.isnull(), ['NOMBRE_ESCUELA','MUNICIPIO','LOCALIDAD',
                                                                  'ALUMNOS_PROGRAMADOS','ALUMNOS_EVALUADOS',
                                                                  'ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO']]
# Out:
# Empty DataFrame
# Columns: [NOMBRE_ESCUELA, MUNICIPIO, LOCALIDAD, ALUMNOS_PROGRAMADOS, ALUMNOS_EVALUADOS, ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO]
# Index: []

# %%
planea.ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO.value_counts()
# Out:
# False    13043
# True      1611
# Name: ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, dtype: int64

# %% [markdown]
# ### 2.3 Limpieza de columna EXTENSIÓN

# %%
planea.EXTENSIÓN.value_counts(dropna=False)
# 333 registros que repiten el CCT (extensiones)
# Se van a eliminar para no tener CCT duplicados
# Out:
# NaN             14321
# EXTENSIÓN 1       246
# EXTENSIÓN 2        47
# EXTENSIÓN 3        14
# EXTENSIÓN 4         7
# EXTENSIÓN 5         3
# EXTENSIÓN 6         2
# EXTENSIÓN 7         1
# EXTENSIÓN 48        1
# TECARIO             1
# EXTENSIÓN 26        1
# EXTENSIÓN 11        1
# EXTENSIÓN 14        1
# EXTENSIÓN 9         1
# EXTENSIÓN 25        1
# EXTENSIÓN 22        1
# EXTENSIÓN 21        1
# EXTENSIÓN 19        1
# EXTENSIÓN 10        1
# EXTENSIÓN 17        1
# EXTENSIÓN 8         1
# Name: EXTENSIÓN, dtype: int64

# %% [markdown]
# ### Hallazgo
#
# + Es raro el nombre de extensión 'TECARIO'

# %%
planea.loc[planea.EXTENSIÓN == 'TECARIO']
# Out:
#       CLAVE DE LA ENTIDAD NOMBRE_ESCUELA CLAVE_ESCUELA     TURNO EXTENSIÓN  \
# 6019                   16    CBTA N0. 69    16DTA0069Q  MATUTINO   TECARIO
#
#         ENTIDAD  MUNICIPIO LOCALIDAD SUBSISTEMA  \
# 6019  MICHOACAN  TACAMBARO  SIN AGUA      DGETA
#
#      GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  pa_ss_mar_mat_III  \
# 6019                            ALTO  ...             26.9               11.4
#
#       pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  ind_IV  ind_gral_len  \
# 6019               6.3     29.6    29.6           59.2    11.1         45.35
#
#       ind_gral_mat  ind_gral
# 6019        49.025    94.375
#
# [1 rows x 48 columns]

# %%
planea.loc[planea.EXTENSIÓN == 'TECARIO',['EXTENSIÓN']] = np.NaN
planea.EXTENSIÓN.value_counts(dropna =False)
# Out:
# NaN             14322
# EXTENSIÓN 1       246
# EXTENSIÓN 2        47
# EXTENSIÓN 3        14
# EXTENSIÓN 4         7
# EXTENSIÓN 5         3
# EXTENSIÓN 6         2
# EXTENSIÓN 9         1
# EXTENSIÓN 7         1
# EXTENSIÓN 48        1
# EXTENSIÓN 26        1
# EXTENSIÓN 11        1
# EXTENSIÓN 14        1
# EXTENSIÓN 25        1
# EXTENSIÓN 22        1
# EXTENSIÓN 21        1
# EXTENSIÓN 19        1
# EXTENSIÓN 10        1
# EXTENSIÓN 17        1
# EXTENSIÓN 8         1
# Name: EXTENSIÓN, dtype: int64

# %% [markdown]
# ### Remplazar NaN en EXTENSIÓN con cadena vacía ''

# %%
# ESTO ES LO QUE REALMENTE COLOCA LA CADENA VACÍA
planea['EXTENSIÓN'] = planea['EXTENSIÓN'].fillna('NO')

# %%
planea.EXTENSIÓN.value_counts()
# Out:
# NO              14322
# EXTENSIÓN 1       246
# EXTENSIÓN 2        47
# EXTENSIÓN 3        14
# EXTENSIÓN 4         7
# EXTENSIÓN 5         3
# EXTENSIÓN 6         2
# EXTENSIÓN 9         1
# EXTENSIÓN 7         1
# EXTENSIÓN 48        1
# EXTENSIÓN 26        1
# EXTENSIÓN 11        1
# EXTENSIÓN 14        1
# EXTENSIÓN 25        1
# EXTENSIÓN 22        1
# EXTENSIÓN 21        1
# EXTENSIÓN 19        1
# EXTENSIÓN 10        1
# EXTENSIÓN 17        1
# EXTENSIÓN 8         1
# Name: EXTENSIÓN, dtype: int64

# %% [markdown]
# planea['EXTENSIÓN'] == planea['EXTENSIÓN'].replace(np.nan, '', regex=True)
#
# NO FUNCIONA

# %%
# Sin NaN
planea.CLAVE_ESCUELA.value_counts()
# Out:
# 31DTA0013G    8
# 02ETC0004A    6
# 12DTA0005J    5
# 02ETC0014H    5
# 14ETC0010Q    5
#              ..
# 15EBH0351S    1
# 13PBH3623V    1
# 18PBH0072K    1
# 15EBH0452Q    1
# 14UBH0066P    1
# Name: CLAVE_ESCUELA, Length: 12857, dtype: int64

# %% [markdown]
# ### Hallazgo
#
# + La clave (CCT) de una escuela se repite de 1 a 8 veces: de 1 a 8 registros con la misma clave

# %%
f'Total de claves de escuelas de las {planea.shape[0]} escuelas evaluadas o adicionadas: {len(planea.CLAVE_ESCUELA.unique())}'
# Out:
# 'Total de claves de escuelas de las 14654 escuelas evaluadas o adicionadas: 12857'

# %%
planea.loc[planea.CLAVE_ESCUELA =='31DTA0013G']
# Out:
#        CLAVE DE LA ENTIDAD NOMBRE_ESCUELA CLAVE_ESCUELA     TURNO  \
# 14045                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14047                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14048                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14049                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14050                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14051                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14053                   31      CBTA # 13    31DTA0013G  MATUTINO
# 14054                   31      CBTA # 13    31DTA0013G  MATUTINO
#
#          EXTENSIÓN  ENTIDAD MUNICIPIO LOCALIDAD SUBSISTEMA  \
# 14045  EXTENSIÓN 7  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14047  EXTENSIÓN 1  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14048  EXTENSIÓN 4  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14049  EXTENSIÓN 2  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14050  EXTENSIÓN 6  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14051  EXTENSIÓN 8  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14053  EXTENSIÓN 3  YUCATAN  XMATKUIL  XMATKUIL      DGETA
# 14054  EXTENSIÓN 5  YUCATAN  XMATKUIL  XMATKUIL      DGETA
#
#       GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 14045                            ALTO  ...             26.9
# 14047                            ALTO  ...             26.9
# 14048                            ALTO  ...             26.9
# 14049                            ALTO  ...             26.9
# 14050                            ALTO  ...             26.9
# 14051                            ALTO  ...             26.9
# 14053                            ALTO  ...             26.9
# 14054                            ALTO  ...             26.9
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 14045               11.4               6.3     26.1     4.2           30.3
# 14047               11.4               6.3     22.6     3.2           25.8
# 14048               11.4               6.3     36.4     0.0           36.4
# 14049               11.4               6.3     14.3     4.8           19.1
# 14050               11.4               6.3     23.5     0.0           23.5
# 14051               11.4               6.3     14.6     2.1           16.7
# 14053               11.4               6.3     15.4     0.0           15.4
# 14054               11.4               6.3     14.3     0.0           14.3
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 14045     8.7        47.825        35.425    83.250
# 14047     4.3        44.125        33.800    77.925
# 14048     0.0        47.775        29.550    77.325
# 14049     0.0        38.100        34.575    72.675
# 14050     0.0        39.700        32.350    72.050
# 14051     4.2        40.125        30.775    70.900
# 14053     0.0        32.700        28.700    61.400
# 14054     0.0        35.725        25.000    60.725
#
# [8 rows x 48 columns]

# %% [markdown]
# ### Hallazgo:
# + Este es un caso con EXTENSIÓN, sin un registro con la columna EXTENSIÓN  con valor NaN (no hay escuela matriz)
# + Es por ello que no podemos borrar las filas de extensiones

# %%
planea.iloc[8786]
# Out:
# CLAVE DE LA ENTIDAD                                                                  20
# NOMBRE_ESCUELA                                                  JOSE MA MORELOS Y PAVON
# CLAVE_ESCUELA                                                                20PBH0054J
# TURNO                                                                        VESPERTINO
# EXTENSIÓN                                                                            NO
# ENTIDAD                                                                          OAXACA
# MUNICIPIO                                                     SANTA MARIA HUAZOLOTITLAN
# LOCALIDAD                                                JOSE MARIA MORELOS (POZA VERDE
# SUBSISTEMA                                                                 PARTICULARES
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                                                    ALTO
# SOSTENIMIENTO                                                              PARTICULARES
# ALUMNOS_PROGRAMADOS                                                                  25
# ALUMNOS_EVALUADOS                                                                    22
# PORCENTAJE_ ALUMNOS_EVALUADOS                                                      88.0
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                                              False
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE                                22
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT                                      22
# esc_leng_I                                                                         86.4
# esc_leng_II                                                                         9.1
# esc_leng_III                                                                        4.5
# esc_leng_IV                                                                         0.0
# ent_ss_mar_len_I                                                                   70.7
# ent_ss_mar_len_II                                                                  15.8
# ent_ss_mar_len_III                                                                 10.5
# ent_ss_mar_len_IV                                                                     3
# pa_ss_mar_len_I                                                                    55.8
# pa_ss_mar_len_II                                                                   16.5
# pa_ss_mar_len_III                                                                  17.6
# pa_ss_mar_len_IV                                                                     10
# esc_mat_I                                                                         100.0
# esc_mat_II                                                                          0.0
# esc_mat_III                                                                         0.0
# esc_mat_IV                                                                          0.0
# ent_ss_mar_mat_I                                                                   79.3
# ent_ss_mar_mat_II                                                                  16.7
# ent_ss_mar_mat_III                                                                  3.6
# ent_ss_mar_mat_IV                                                                   0.3
# pa_ss_mar_mat_I                                                                      67
# pa_ss_mar_mat_II                                                                   19.7
# pa_ss_mar_mat_III                                                                   8.2
# pa_ss_mar_mat_IV                                                                    5.1
# ind_len                                                                             4.5
# ind_mat                                                                             0.0
# ind-compuesto                                                                       4.5
# ind_IV                                                                              0.0
# ind_gral_len                                                                     29.525
# ind_gral_mat                                                                       25.0
# ind_gral                                                                         54.525
# Name: 8786, dtype: object

# %%
# Para chequear si tiene valores nulos
planea['EXTENSIÓN'].isnull().values.any()
# Out:
# False

# %%
# Para contar NaN en una columna
planea['EXTENSIÓN'].isnull().sum()
# Out:
# 0

# %%
# Para mostrar con EXTENSIÓN 1
planea.loc[planea.EXTENSIÓN =='EXTENSIÓN 1']
# Out:
#        CLAVE DE LA ENTIDAD                                     NOMBRE_ESCUELA  \
# 303                      2                                          URBIVILLA
# 351                      2                                PRIMO TAPIA ADULTOS
# 355                      2  CENTRO DE BACHILLERATO TECNOLÓGICO AGROPECUARI...
# 377                      2                                        BELLA VISTA
# 394                      2                                        BELLA VISTA
# ...                    ...                                                ...
# 14339                   32  CENTRO DE BACHILLERATO TECNOLÓGICO AGROPECUARI...
# 14349                   32       COLEGIO DE BACHILLERES PLANTEL GENARO CODINA
# 14356                   32    COLEGIO DE BACHILLERES PLANTEL IGNACIO ZARAGOZA
# 14471                   21                      PREP. ALFONSO CALDERÓN MORENO
# 14487                   32               COLEGIO DE BACHILLERES PLANTEL PINOS
#
#       CLAVE_ESCUELA       TURNO    EXTENSIÓN          ENTIDAD  \
# 303      02ETC0006Z  VESPERTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 351      02ETC0016F  VESPERTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 355      02DTA0041H    MATUTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 377      02ETC0018D  VESPERTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 394      02ETC0018D    MATUTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# ...             ...         ...          ...              ...
# 14339    32DTA0006W    MATUTINO  EXTENSIÓN 1        ZACATECAS
# 14349    32ECB0018I    MATUTINO  EXTENSIÓN 1        ZACATECAS
# 14356    32ECB0027Q  VESPERTINO  EXTENSIÓN 1        ZACATECAS
# 14471    21UBH0004M    MATUTINO  EXTENSIÓN 1           PUEBLA
# 14487    32ECB0008B    MATUTINO  EXTENSIÓN 1        ZACATECAS
#
#                 MUNICIPIO           LOCALIDAD             SUBSISTEMA  \
# 303               TIJUANA             TIJUANA                 CECYTE
# 351    PLAYAS DE ROSARITO         PRIMO TAPIA                 CECYTE
# 355              MEXICALI  POB. BENITO JUAREZ                  DGETA
# 377              MEXICALI            MEXICALI                 CECYTE
# 394              MEXICALI            MEXICALI                 CECYTE
# ...                   ...                 ...                    ...
# 14339           FRESNILLO         RÍO FLORIDO                  DGETA
# 14349       GENARO CODINA             PERALES                 COBACH
# 14356    NORIA DE ANGELES    NORIA DE ANGELES                 COBACH
# 14471             ACAJETE             ACAJETE  BACHILLERATO AUTÓNOMO
# 14487               PINOS           EL OBRAJE                 COBACH
#
#       GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 303                          MUY BAJO  ...             32.8
# 351                              BAJO  ...               31
# 355                             MEDIO  ...             27.2
# 377                          MUY BAJO  ...             32.8
# 394                          MUY BAJO  ...             32.8
# ...                               ...  ...              ...
# 14339                            BAJO  ...               30
# 14349                           MEDIO  ...             27.6
# 14356                            ALTO  ...             24.3
# 14471                            ALTO  ...             22.6
# 14487                            BAJO  ...             28.4
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 303                 11.4               3.8     27.7     4.9           32.6
# 351                 12.8               5.7      3.0    70.6           73.6
# 355                  9.1               4.1      3.0     0.0            3.0
# 377                 11.4               3.8     37.4    31.9           69.3
# 394                 11.4               3.8     51.1     6.8           57.9
# ...                  ...               ...      ...     ...            ...
# 14339               12.8               7.1     48.0    20.0           68.0
# 14349               11.3               5.1     17.2     6.9           24.1
# 14356                8.3               3.7     16.7    11.8           28.5
# 14471                9.5               3.2     70.6    33.4          104.0
# 14487               11.2               5.1     25.0    22.5           47.5
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 303       4.9        44.750        32.125    76.875
# 351      11.8        34.075        67.650   101.725
# 355       0.0        30.300        27.275    57.575
# 377      19.8        53.900        56.050   109.950
# 394      17.8        59.425        39.150    98.575
# ...       ...           ...           ...       ...
# 14339    20.0        61.000        41.000   102.000
# 14349     6.9        42.225        30.175    72.400
# 14356     5.6        40.300        35.300    75.600
# 14471    50.5        72.800        56.100   128.900
# 14487    10.0        44.375        41.875    86.250
#
# [246 rows x 48 columns]

# %% [markdown]
# ### Eliminar filas con extensión y no ser la extensión 1
#
# + Elimina filas con EXTENSIÓN 2 en lo adelante

# %%
# Eliminar filas que cumplan condición de no estar vacía la extensón y no ser la extensión 1
planea.drop(planea[(planea.EXTENSIÓN != 'NO') & (planea.EXTENSIÓN !='EXTENSIÓN 1')].index, inplace=True)
planea.shape
planea.EXTENSIÓN.value_counts()
# Out:
# (14568, 48)
# NO             14322
# EXTENSIÓN 1      246
# Name: EXTENSIÓN, dtype: int64

# %%
planea
# Out:
#        CLAVE DE LA ENTIDAD                                     NOMBRE_ESCUELA  \
# 0                       12              UNIDAD ACADÉMICA: PREPARATORIA NO. 36
# 1                        1                  CBTA NO. 40 JOSÉ GUADALUPE POSADA
# 2                       12              UNIDAD ACADÉMICA: PREPARATORIA NO. 36
# 3                       12  CENTRO DE ESTUDIOS DEL BACHILLERATO GENERAL JE...
# 4                        1                        TELEBACHILLERATO VALLADOLID
# ...                    ...                                                ...
# 14649                   33                  SISTEMA EDUCATIVO NACIONAL *10344
# 14650                   33          INSTITUTO SONORENSE DE EDUCACION * 060911
# 14651                   33                             COLEGIO CALMECAC *9683
# 14652                   33                  SISTEMA EDUCATIVO NACIONAL *10343
# 14653                   33  ESCUELA REGIONAL DE EDUCACION MEDIA SUPERIOR D...
#
#       CLAVE_ESCUELA       TURNO EXTENSIÓN         ENTIDAD        MUNICIPIO  \
# 0        12UBH0009Z    MATUTINO        NO        GUERRERO     EDUARDO NERI
# 1        01DTA0040J    MATUTINO        NO  AGUASCALIENTES         ASIENTOS
# 2        12UBH0009Z  VESPERTINO        NO        GUERRERO     EDUARDO NERI
# 3        12PBH0012B    MATUTINO        NO        GUERRERO     EDUARDO NERI
# 4        01ETH0016B    MATUTINO        NO  AGUASCALIENTES      JESUS MARIA
# ...             ...         ...       ...             ...              ...
# 14649    13DEX0001E    MATUTINO        NO         HIDALGO  PACHUCA DE SOTO
# 14650    26EEX0001H    MATUTINO        NO          SONORA       HERMOSILLO
# 14651    14PBJ0010Q    MATUTINO        NO         JALISCO          ZAPOPAN
# 14652    11DEX0001G    MATUTINO        NO      GUANAJUATO           CELAYA
# 14653    14UBH0066P    MATUTINO        NO         JALISCO          OCOTLAN
#
#               LOCALIDAD             SUBSISTEMA  \
# 0      ZUMPANGO DEL RIO  BACHILLERATO AUTÓNOMO
# 1          VILLA JUAREZ                  DGETA
# 2      ZUMPANGO DEL RIO  BACHILLERATO AUTÓNOMO
# 3      ZUMPANGO DEL RIO           PARTICULARES
# 4            VALLADOLID      TELEBACHILLERATOS
# ...                 ...                    ...
# 14649   PACHUCA DE SOTO                PÚBLICO
# 14650        HERMOSILLO                PÚBLICO
# 14651           ZAPOPAN           PARTICULARES
# 14652            CELAYA                PÚBLICO
# 14653           OCOTLAN                PÚBLICO
#
#       GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 0                                ALTO  ...             22.6
# 1                                BAJO  ...               30
# 2                                ALTO  ...             22.6
# 3                                ALTO  ...             19.7
# 4                            MUY BAJO  ...             26.9
# ...                               ...  ...              ...
# 14649                            BAJO  ...                0
# 14650                        MUY BAJO  ...                0
# 14651                        MUY BAJO  ...                0
# 14652                            BAJO  ...                0
# 14653                        MUY BAJO  ...                0
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 0                    9.5               3.2     27.6     6.4           34.0
# 1                   12.8               7.1     44.5    16.9           61.4
# 2                    9.5               3.2      7.2     3.5           10.7
# 3                    8.2               5.1      0.0     0.0            0.0
# 4                    6.1               1.2     30.0     5.0           35.0
# ...                  ...               ...      ...     ...            ...
# 14649                  0                 0      0.0     0.0            0.0
# 14650                  0                 0      0.0     0.0            0.0
# 14651                  0                 0      0.0     0.0            0.0
# 14652                  0                 0      0.0     0.0            0.0
# 14653                  0                 0      0.0     0.0            0.0
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 0         3.8        47.600        35.775    83.375
# 1        16.5        56.550        43.850   100.400
# 2         1.8        33.100        29.825    62.925
# 3         0.0        33.325        25.000    58.325
# 4         5.0        45.000        36.250    81.250
# ...       ...           ...           ...       ...
# 14649     0.0         0.000         0.000     0.000
# 14650     0.0         0.000         0.000     0.000
# 14651     0.0         0.000         0.000     0.000
# 14652     0.0         0.000         0.000     0.000
# 14653     0.0         0.000         0.000     0.000
#
# [14568 rows x 48 columns]

# %%
# Para mostrar con EXTENSIÓN 1
planea.loc[planea.EXTENSIÓN =='EXTENSIÓN 1']
# Out:
#        CLAVE DE LA ENTIDAD                                     NOMBRE_ESCUELA  \
# 303                      2                                          URBIVILLA
# 351                      2                                PRIMO TAPIA ADULTOS
# 355                      2  CENTRO DE BACHILLERATO TECNOLÓGICO AGROPECUARI...
# 377                      2                                        BELLA VISTA
# 394                      2                                        BELLA VISTA
# ...                    ...                                                ...
# 14339                   32  CENTRO DE BACHILLERATO TECNOLÓGICO AGROPECUARI...
# 14349                   32       COLEGIO DE BACHILLERES PLANTEL GENARO CODINA
# 14356                   32    COLEGIO DE BACHILLERES PLANTEL IGNACIO ZARAGOZA
# 14471                   21                      PREP. ALFONSO CALDERÓN MORENO
# 14487                   32               COLEGIO DE BACHILLERES PLANTEL PINOS
#
#       CLAVE_ESCUELA       TURNO    EXTENSIÓN          ENTIDAD  \
# 303      02ETC0006Z  VESPERTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 351      02ETC0016F  VESPERTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 355      02DTA0041H    MATUTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 377      02ETC0018D  VESPERTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# 394      02ETC0018D    MATUTINO  EXTENSIÓN 1  BAJA CALIFORNIA
# ...             ...         ...          ...              ...
# 14339    32DTA0006W    MATUTINO  EXTENSIÓN 1        ZACATECAS
# 14349    32ECB0018I    MATUTINO  EXTENSIÓN 1        ZACATECAS
# 14356    32ECB0027Q  VESPERTINO  EXTENSIÓN 1        ZACATECAS
# 14471    21UBH0004M    MATUTINO  EXTENSIÓN 1           PUEBLA
# 14487    32ECB0008B    MATUTINO  EXTENSIÓN 1        ZACATECAS
#
#                 MUNICIPIO           LOCALIDAD             SUBSISTEMA  \
# 303               TIJUANA             TIJUANA                 CECYTE
# 351    PLAYAS DE ROSARITO         PRIMO TAPIA                 CECYTE
# 355              MEXICALI  POB. BENITO JUAREZ                  DGETA
# 377              MEXICALI            MEXICALI                 CECYTE
# 394              MEXICALI            MEXICALI                 CECYTE
# ...                   ...                 ...                    ...
# 14339           FRESNILLO         RÍO FLORIDO                  DGETA
# 14349       GENARO CODINA             PERALES                 COBACH
# 14356    NORIA DE ANGELES    NORIA DE ANGELES                 COBACH
# 14471             ACAJETE             ACAJETE  BACHILLERATO AUTÓNOMO
# 14487               PINOS           EL OBRAJE                 COBACH
#
#       GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 303                          MUY BAJO  ...             32.8
# 351                              BAJO  ...               31
# 355                             MEDIO  ...             27.2
# 377                          MUY BAJO  ...             32.8
# 394                          MUY BAJO  ...             32.8
# ...                               ...  ...              ...
# 14339                            BAJO  ...               30
# 14349                           MEDIO  ...             27.6
# 14356                            ALTO  ...             24.3
# 14471                            ALTO  ...             22.6
# 14487                            BAJO  ...             28.4
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 303                 11.4               3.8     27.7     4.9           32.6
# 351                 12.8               5.7      3.0    70.6           73.6
# 355                  9.1               4.1      3.0     0.0            3.0
# 377                 11.4               3.8     37.4    31.9           69.3
# 394                 11.4               3.8     51.1     6.8           57.9
# ...                  ...               ...      ...     ...            ...
# 14339               12.8               7.1     48.0    20.0           68.0
# 14349               11.3               5.1     17.2     6.9           24.1
# 14356                8.3               3.7     16.7    11.8           28.5
# 14471                9.5               3.2     70.6    33.4          104.0
# 14487               11.2               5.1     25.0    22.5           47.5
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 303       4.9        44.750        32.125    76.875
# 351      11.8        34.075        67.650   101.725
# 355       0.0        30.300        27.275    57.575
# 377      19.8        53.900        56.050   109.950
# 394      17.8        59.425        39.150    98.575
# ...       ...           ...           ...       ...
# 14339    20.0        61.000        41.000   102.000
# 14349     6.9        42.225        30.175    72.400
# 14356     5.6        40.300        35.300    75.600
# 14471    50.5        72.800        56.100   128.900
# 14487    10.0        44.375        41.875    86.250
#
# [246 rows x 48 columns]

# %%
count_claves =planea.CLAVE_ESCUELA.value_counts()
count_claves = pd.DataFrame(count_claves)
count_claves
type(count_claves)
# Out:
#             CLAVE_ESCUELA
# 12DPT0006K              4
# 25UBH0019K              4
# 11PBH3810R              3
# 25UBH0002K              3
# 14UBH0031Z              3
# ...                   ...
# 13PBH0002U              1
# 15ETC0035Y              1
# 15EBH0430E              1
# 15EBH0110U              1
# 14UBH0066P              1
#
# [12848 rows x 1 columns]
# pandas.core.frame.DataFrame

# %%
f'{len(count_claves)} claves (CCT) diferentes'
# Out:
# '12848 claves (CCT) diferentes'

# %%
count_claves.columns
# Out:
# Index(['CLAVE_ESCUELA'], dtype='object')

# %%
# Eliminar las claves de escuelas con una sola fila (un solo turno-extensión)
count_claves.drop(count_claves[count_claves.CLAVE_ESCUELA == 1].index,inplace= True)
count_claves
# Out:
#             CLAVE_ESCUELA
# 12DPT0006K              4
# 25UBH0019K              4
# 11PBH3810R              3
# 25UBH0002K              3
# 14UBH0031Z              3
# ...                   ...
# 14UBH0142E              2
# 15UBH0012K              2
# 05DCT0048W              2
# 15PBH6025R              2
# 05DCT0083B              2
#
# [1619 rows x 1 columns]

# %% [markdown]
# ### Hallazgo:
# + La mayoría de las escuelas NO aparece más de una vez. Lo más probable es que, además de las extensiones, aparezcan más de una vez por los turnos matutino y vespertino

# %%
count_claves[['CLAVE_ESCUELA']].value_counts()
# Out:
# CLAVE_ESCUELA
# 2                1520
# 3                  97
# 4                   2
# dtype: int64

# %%
f'{len(count_claves)} claves (CCT) repetidas'
# Out:
# '1619 claves (CCT) repetidas'

# %%
planea.loc[planea.CLAVE_ESCUELA =='12DPT0006K',['CLAVE_ESCUELA','TURNO','EXTENSIÓN', 'ind_gral']]
# El mejor resultado lo obtuvo la matriz matutina y el peor la matriz vespertina
# Out:
#      CLAVE_ESCUELA       TURNO    EXTENSIÓN  ind_gral
# 3724    12DPT0006K    MATUTINO           NO    81.275
# 3735    12DPT0006K    MATUTINO  EXTENSIÓN 1    74.950
# 3739    12DPT0006K  VESPERTINO  EXTENSIÓN 1    65.275
# 3742    12DPT0006K  VESPERTINO           NO    61.125

# %% [markdown]
# ### Hallazgo:
#
# + La matriz tiene dos turnos y la extensión 1 también. Nos quedaremos con la matriz matutina

# %%
planea.loc[planea.CLAVE_ESCUELA =='25UBH0019K',['CLAVE_ESCUELA','TURNO','EXTENSIÓN', 'ind_gral']] 
# El mejor resultado lo obtuvo la matriz matutina y el peor la extensión vespertina
# Out:
#       CLAVE_ESCUELA       TURNO    EXTENSIÓN  ind_gral
# 8155     25UBH0019K    MATUTINO  EXTENSIÓN 1    55.650
# 8156     25UBH0019K  VESPERTINO  EXTENSIÓN 1    52.450
# 10005    25UBH0019K    MATUTINO           NO    97.425
# 10010    25UBH0019K  VESPERTINO           NO    66.050

# %%
planea.loc[planea.CLAVE_ESCUELA =='14UBH0015I',['CLAVE_ESCUELA','TURNO','EXTENSIÓN', 'ind_gral']] 
# Matriz con los 3 turnos y el mejor resultado en el matutino
# Out:
#       CLAVE_ESCUELA       TURNO EXTENSIÓN  ind_gral
# 13622    14UBH0015I    MATUTINO        NO   104.275
# 13623    14UBH0015I  VESPERTINO        NO    94.575
# 13626    14UBH0015I    NOCTURNO        NO    74.600

# %%
planea.loc[planea.CLAVE_ESCUELA =='21UBH0038C',['CLAVE_ESCUELA','TURNO','EXTENSIÓN', 'ind_gral']]
# Mejor resultado la extensión matutina
# Out:
#      CLAVE_ESCUELA       TURNO    EXTENSIÓN  ind_gral
# 3919    21UBH0038C    MATUTINO  EXTENSIÓN 1   167.925
# 5585    21UBH0038C  VESPERTINO           NO   162.375
# 5587    21UBH0038C    MATUTINO           NO   153.750

# %%
planea.loc[planea.CLAVE_ESCUELA =='29DCT0144I',['CLAVE_ESCUELA','TURNO','EXTENSIÓN', 'ind_gral']]
# Out:
#       CLAVE_ESCUELA       TURNO EXTENSIÓN  ind_gral
# 11824    29DCT0144I    MATUTINO        NO    133.30
# 11825    29DCT0144I  VESPERTINO        NO     97.95

# %% [markdown]
# ### Hallazgo
# + Las repeticiones son porque hay turnos matutinos y vespertinos, además de la extensión
# + No siempre la matriz o el turno matutino tienen el mejor ind_gral

# %% [markdown]
# ## 3. Eliminar CCT duplicados con menor ind_gral
#
# + Sin importar si es matriz o EXTENSIÓN 1
# + Localizar filas con esa condición
# + Ordenar y quedarse con fila de mayor ind_gral

# %%
print(len(planea))
# Out:
# 14568

# %%
planea.loc[planea['CLAVE_ESCUELA'] == '31DTA0013G']
# Out:
#        CLAVE DE LA ENTIDAD NOMBRE_ESCUELA CLAVE_ESCUELA     TURNO  \
# 14047                   31      CBTA # 13    31DTA0013G  MATUTINO
#
#          EXTENSIÓN  ENTIDAD MUNICIPIO LOCALIDAD SUBSISTEMA  \
# 14047  EXTENSIÓN 1  YUCATAN  XMATKUIL  XMATKUIL      DGETA
#
#       GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 14047                            ALTO  ...             26.9
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 14047               11.4               6.3     22.6     3.2           25.8
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 14047     4.3        44.125          33.8    77.925
#
# [1 rows x 48 columns]

# %%
# Para cada CCT (algo más de 1600)
for i in count_claves.index:
    f = planea.loc[(planea.CLAVE_ESCUELA == i)] # Localiza registros de PLANEA con igual CCT. únicos,duplicados, triplicados y más
    ordenado = f.sort_values('ind_gral') # ordenado de menor índice general a mayor de un mismo CCT
    ordenado.drop(ordenado.tail(1).index,inplace=True)  # Elimina el último de mayor ind_gral
    # Elimina las filas de ordenado (con los índices que no son menores) en planea
    planea.drop(ordenado.index,inplace=True)
        
print(len(planea))
# Out:
# 12848

# %%
planea.loc[planea['CLAVE_ESCUELA'] == '31DTA0013G']
# Out:
#        CLAVE DE LA ENTIDAD NOMBRE_ESCUELA CLAVE_ESCUELA     TURNO  \
# 14047                   31      CBTA # 13    31DTA0013G  MATUTINO
#
#          EXTENSIÓN  ENTIDAD MUNICIPIO LOCALIDAD SUBSISTEMA  \
# 14047  EXTENSIÓN 1  YUCATAN  XMATKUIL  XMATKUIL      DGETA
#
#       GRADO_MARGINACIÓN_LOCALIDAD_CCT  ... pa_ss_mar_mat_II  \
# 14047                            ALTO  ...             26.9
#
#        pa_ss_mar_mat_III  pa_ss_mar_mat_IV  ind_len ind_mat  ind-compuesto  \
# 14047               11.4               6.3     22.6     3.2           25.8
#
#        ind_IV  ind_gral_len  ind_gral_mat  ind_gral
# 14047     4.3        44.125          33.8    77.925
#
# [1 rows x 48 columns]

# %% [markdown]
# ### Exploración de ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT

# %%
planea.ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT.value_counts()
# Out:
# 16     288
# 13     268
# 17     267
# 19     263
# 15     259
#       ...
# 466      1
# 606      1
# 448      1
# 434      1
# 447      1
# Name: ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT, Length: 465, dtype: int64

# %%
planea[planea['ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT'].isin([np.nan, np.inf, -np.inf])]
# Out:
# Empty DataFrame
# Columns: [CLAVE DE LA ENTIDAD, NOMBRE_ESCUELA, CLAVE_ESCUELA, TURNO, EXTENSIÓN, ENTIDAD, MUNICIPIO, LOCALIDAD, SUBSISTEMA, GRADO_MARGINACIÓN_LOCALIDAD_CCT, SOSTENIMIENTO, ALUMNOS_PROGRAMADOS, ALUMNOS_EVALUADOS, PORCENTAJE_ ALUMNOS_EVALUADOS, ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE, ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT, esc_leng_I, esc_leng_II, esc_leng_III, esc_leng_IV, ent_ss_mar_len_I, ent_ss_mar_len_II, ent_ss_mar_len_III, ent_ss_mar_len_IV, pa_ss_mar_len_I, pa_ss_mar_len_II, pa_ss_mar_len_III, pa_ss_mar_len_IV, esc_mat_I, esc_mat_II, esc_mat_III, esc_mat_IV, ent_ss_mar_mat_I, ent_ss_mar_mat_II, ent_ss_mar_mat_III, ent_ss_mar_mat_IV, pa_ss_mar_mat_I, pa_ss_mar_mat_II, pa_ss_mar_mat_III, pa_ss_mar_mat_IV, ind_len, ind_mat, ind-compuesto, ind_IV, ind_gral_len, ind_gral_mat, ind_gral]
# Index: []
#
# [0 rows x 48 columns]

# %% [markdown]
# ### Nueva verificación de nulos

# %%
# Cantidad de filas con al menos un nan. Es lento
#sum(planea.apply(lambda x: sum(x.isnull().values), axis = 1)>0)
# Hubo null antes de imputar extensión y cambiar a bool'ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO'
# Después ya no hay nulos

# %%
# Otra forma de hacer lo anterior de manera más rápida
# Cantidad de filas con al menos un valor faltante
(planea.isna().sum(axis=1) > 0).sum()
# Out:
# 0

# %%
# Cantidad e columnas con al menos un valor faltante
(planea.isna().sum(axis=0) > 0).sum()
# Out:
# 0

# %%
planea_nan = planea[planea.isna().any(axis=1)]
planea_nan
# Out:
# Empty DataFrame
# Columns: [CLAVE DE LA ENTIDAD, NOMBRE_ESCUELA, CLAVE_ESCUELA, TURNO, EXTENSIÓN, ENTIDAD, MUNICIPIO, LOCALIDAD, SUBSISTEMA, GRADO_MARGINACIÓN_LOCALIDAD_CCT, SOSTENIMIENTO, ALUMNOS_PROGRAMADOS, ALUMNOS_EVALUADOS, PORCENTAJE_ ALUMNOS_EVALUADOS, ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE, ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT, esc_leng_I, esc_leng_II, esc_leng_III, esc_leng_IV, ent_ss_mar_len_I, ent_ss_mar_len_II, ent_ss_mar_len_III, ent_ss_mar_len_IV, pa_ss_mar_len_I, pa_ss_mar_len_II, pa_ss_mar_len_III, pa_ss_mar_len_IV, esc_mat_I, esc_mat_II, esc_mat_III, esc_mat_IV, ent_ss_mar_mat_I, ent_ss_mar_mat_II, ent_ss_mar_mat_III, ent_ss_mar_mat_IV, pa_ss_mar_mat_I, pa_ss_mar_mat_II, pa_ss_mar_mat_III, pa_ss_mar_mat_IV, ind_len, ind_mat, ind-compuesto, ind_IV, ind_gral_len, ind_gral_mat, ind_gral]
# Index: []
#
# [0 rows x 48 columns]

# %% [markdown]
# ### Convertir a tipos de menos memoria
#
# + Usando dict comprehension o de uno por uno
# + Memoria usada antes y después de la reducción

# %%
# Usando un dict por comprensión para cambiar todos los de un mismo tipo
#df_mod = df_mod.astype({col: 'int32' for col in df_mod.select_dtypes('int64').columns})  # dict por comprensión

# %%
planea.memory_usage(index=True,deep=False).sum()/1024
# Out:
# 4918.375

# %%
# Aquí se hace de uno por uno
planea['CLAVE DE LA ENTIDAD'] = planea['CLAVE DE LA ENTIDAD'].astype('int32')
planea['ALUMNOS_PROGRAMADOS'] = planea['ALUMNOS_PROGRAMADOS'].astype('int32')
planea['ALUMNOS_EVALUADOS'] = planea['ALUMNOS_EVALUADOS'].astype('int32')
planea['ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE'] = planea['ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE'].astype('int32')
planea['ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT'] = planea['ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT'].astype('int32')

# %%
planea.memory_usage(index=True,deep=False).sum()/1024
# Out:
# 4667.4375

# %% [markdown]
# ### Verificar nulos y tipos

# %%
planea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12848 entries, 0 to 14653
# Data columns (total 48 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   CLAVE DE LA ENTIDAD                                    12848 non-null  int32
#  1   NOMBRE_ESCUELA                                         12848 non-null  object
#  2   CLAVE_ESCUELA                                          12848 non-null  object
#  3   TURNO                                                  12848 non-null  object
#  4   EXTENSIÓN                                              12848 non-null  object
#  5   ENTIDAD                                                12848 non-null  object
#  6   MUNICIPIO                                              12848 non-null  object
#  7   LOCALIDAD                                              12848 non-null  object
#  8   SUBSISTEMA                                             12848 non-null  object
#  9   GRADO_MARGINACIÓN_LOCALIDAD_CCT                        12848 non-null  object
#  10  SOSTENIMIENTO                                          12848 non-null  object
#  11  ALUMNOS_PROGRAMADOS                                    12848 non-null  int32
#  12  ALUMNOS_EVALUADOS                                      12848 non-null  int32
#  13  PORCENTAJE_ ALUMNOS_EVALUADOS                          12848 non-null  float64
#  14  ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                   12848 non-null  object
#  15  ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE  12848 non-null  int32
#  16  ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT        12848 non-null  int32
#  17  esc_leng_I                                             12848 non-null  float64
#  18  esc_leng_II                                            12848 non-null  float64
#  19  esc_leng_III                                           12848 non-null  float64
#  20  esc_leng_IV                                            12848 non-null  float64
#  21  ent_ss_mar_len_I                                       12848 non-null  object
#  22  ent_ss_mar_len_II                                      12848 non-null  object
#  23  ent_ss_mar_len_III                                     12848 non-null  object
#  24  ent_ss_mar_len_IV                                      12848 non-null  object
#  25  pa_ss_mar_len_I                                        12848 non-null  object
#  26  pa_ss_mar_len_II                                       12848 non-null  object
#  27  pa_ss_mar_len_III                                      12848 non-null  object
#  28  pa_ss_mar_len_IV                                       12848 non-null  object
#  29  esc_mat_I                                              12848 non-null  float64
#  30  esc_mat_II                                             12848 non-null  float64
#  31  esc_mat_III                                            12848 non-null  float64
#  32  esc_mat_IV                                             12848 non-null  float64
#  33  ent_ss_mar_mat_I                                       12848 non-null  object
#  34  ent_ss_mar_mat_II                                      12848 non-null  object
#  35  ent_ss_mar_mat_III                                     12848 non-null  object
#  36  ent_ss_mar_mat_IV                                      12848 non-null  object
#  37  pa_ss_mar_mat_I                                        12848 non-null  object
#  38  pa_ss_mar_mat_II                                       12848 non-null  object
#  39  pa_ss_mar_mat_III                                      12848 non-null  object
#  40  pa_ss_mar_mat_IV                                       12848 non-null  object
#  41  ind_len                                                12848 non-null  float64
#  42  ind_mat                                                12848 non-null  float64
#  43  ind-compuesto                                          12848 non-null  float64
#  44  ind_IV                                                 12848 non-null  float64
#  45  ind_gral_len                                           12848 non-null  float64
#  46  ind_gral_mat                                           12848 non-null  float64
#  47  ind_gral                                               12848 non-null  float64
# dtypes: float64(16), int32(5), object(27)
# memory usage: 4.6+ MB

# %% [markdown]
# ## 4. Imputar con 0 donde aparece 'S/R' (sin respuesta)

# %%
# Localizar donde hay 'S/R'
planea.loc[planea.ent_ss_mar_mat_I == 'S/R',['ent_ss_mar_len_I','ent_ss_mar_mat_I',
                                             'pa_ss_mar_mat_I','pa_ss_mar_mat_II','pa_ss_mar_mat_III','pa_ss_mar_mat_IV']]
# Out:
#       ent_ss_mar_len_I ent_ss_mar_mat_I pa_ss_mar_mat_I pa_ss_mar_mat_II  \
# 37                 S/R              S/R             S/R              S/R
# 39                 S/R              S/R            64.3             22.1
# 54                 S/R              S/R             S/R              S/R
# 56                 S/R              S/R            60.9               26
# 65                 S/R              S/R            55.1             28.6
# ...                ...              ...             ...              ...
# 14371              S/R              S/R            57.7             29.3
# 14468              S/R              S/R            59.6             27.2
# 14483              S/R              S/R            51.6             27.3
# 14496              S/R              S/R            54.2             31.7
# 14536              S/R              S/R              54             25.2
#
#       pa_ss_mar_mat_III pa_ss_mar_mat_IV
# 37                  S/R              S/R
# 39                  9.5              4.2
# 54                  S/R              S/R
# 56                  9.1                4
# 65                 11.6              4.7
# ...                 ...              ...
# 14371               8.9              4.1
# 14468               9.1              4.1
# 14483              16.5              4.7
# 14496                10                4
# 14536              12.4              8.4
#
# [193 rows x 6 columns]

# %% [markdown]
# ### Hallazgo
# + Hay 193 filas con valores de S/R

# %%
# Reemplazar todos los S/R
planea.replace('S/R',0,inplace=True)

# %%
planea.loc[planea.ent_ss_mar_mat_I == 'S/R',['ent_ss_mar_len_I','ent_ss_mar_mat_I',
                                             'pa_ss_mar_mat_I','pa_ss_mar_mat_II','pa_ss_mar_mat_III','pa_ss_mar_mat_IV']]
# Out:
# Empty DataFrame
# Columns: [ent_ss_mar_len_I, ent_ss_mar_mat_I, pa_ss_mar_mat_I, pa_ss_mar_mat_II, pa_ss_mar_mat_III, pa_ss_mar_mat_IV]
# Index: []

# %%
planea.esc_mat_I.value_counts()
# Out:
# 100.0    496
# 0.0      436
# 50.0     303
# 66.7     261
# 75.0     234
#         ...
# 60.1       1
# 11.2       1
# 93.0       1
# 89.6       1
# 50.2       1
# Name: esc_mat_I, Length: 962, dtype: int64

# %%
planea.loc[planea.esc_mat_I == '*****']
# Out:
# Empty DataFrame
# Columns: [CLAVE DE LA ENTIDAD, NOMBRE_ESCUELA, CLAVE_ESCUELA, TURNO, EXTENSIÓN, ENTIDAD, MUNICIPIO, LOCALIDAD, SUBSISTEMA, GRADO_MARGINACIÓN_LOCALIDAD_CCT, SOSTENIMIENTO, ALUMNOS_PROGRAMADOS, ALUMNOS_EVALUADOS, PORCENTAJE_ ALUMNOS_EVALUADOS, ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO, ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE, ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT, esc_leng_I, esc_leng_II, esc_leng_III, esc_leng_IV, ent_ss_mar_len_I, ent_ss_mar_len_II, ent_ss_mar_len_III, ent_ss_mar_len_IV, pa_ss_mar_len_I, pa_ss_mar_len_II, pa_ss_mar_len_III, pa_ss_mar_len_IV, esc_mat_I, esc_mat_II, esc_mat_III, esc_mat_IV, ent_ss_mar_mat_I, ent_ss_mar_mat_II, ent_ss_mar_mat_III, ent_ss_mar_mat_IV, pa_ss_mar_mat_I, pa_ss_mar_mat_II, pa_ss_mar_mat_III, pa_ss_mar_mat_IV, ind_len, ind_mat, ind-compuesto, ind_IV, ind_gral_len, ind_gral_mat, ind_gral]
# Index: []
#
# [0 rows x 48 columns]

# %%
planea.loc[planea.ent_ss_mar_mat_I == 'S/R',['ent_ss_mar_len_I','ent_ss_mar_mat_I']]
# Out:
# Empty DataFrame
# Columns: [ent_ss_mar_len_I, ent_ss_mar_mat_I]
# Index: []

# %% [markdown]
# ### Reducir de float64 a float32

# %%
lista = ['esc_leng_I', 'esc_leng_II', 'esc_leng_III', 'esc_leng_IV',
       'ent_ss_mar_len_I', 'ent_ss_mar_len_II', 'ent_ss_mar_len_III',
       'ent_ss_mar_len_IV', 'pa_ss_mar_len_I', 'pa_ss_mar_len_II',
       'pa_ss_mar_len_III', 'pa_ss_mar_len_IV', 'esc_mat_I', 'esc_mat_II',
       'esc_mat_III', 'esc_mat_IV', 'ent_ss_mar_mat_I', 'ent_ss_mar_mat_II',
       'ent_ss_mar_mat_III', 'ent_ss_mar_mat_IV', 'pa_ss_mar_mat_I',
       'pa_ss_mar_mat_II', 'pa_ss_mar_mat_III', 'pa_ss_mar_mat_IV']
for i in lista:
    planea[i] = planea[i].astype('float32')

# %%
planea.memory_usage(index=True,deep=False).sum()/1024
# Out:
# 3375.109375

# %%
planea.dtypes
# Out:
# CLAVE DE LA ENTIDAD                                        int32
# NOMBRE_ESCUELA                                            object
# CLAVE_ESCUELA                                             object
# TURNO                                                     object
# EXTENSIÓN                                                 object
# ENTIDAD                                                   object
# MUNICIPIO                                                 object
# LOCALIDAD                                                 object
# SUBSISTEMA                                                object
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                           object
# SOSTENIMIENTO                                             object
# ALUMNOS_PROGRAMADOS                                        int32
# ALUMNOS_EVALUADOS                                          int32
# PORCENTAJE_ ALUMNOS_EVALUADOS                            float64
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                        bool
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE      int32
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT            int32
# esc_leng_I                                               float32
# esc_leng_II                                              float32
# esc_leng_III                                             float32
# esc_leng_IV                                              float32
# ent_ss_mar_len_I                                         float32
# ent_ss_mar_len_II                                        float32
# ent_ss_mar_len_III                                       float32
# ent_ss_mar_len_IV                                        float32
# pa_ss_mar_len_I                                          float32
# pa_ss_mar_len_II                                         float32
# pa_ss_mar_len_III                                        float32
# pa_ss_mar_len_IV                                         float32
# esc_mat_I                                                float32
# esc_mat_II                                               float32
# esc_mat_III                                              float32
# esc_mat_IV                                               float32
# ent_ss_mar_mat_I                                         float32
# ent_ss_mar_mat_II                                        float32
# ent_ss_mar_mat_III                                       float32
# ent_ss_mar_mat_IV                                        float32
# pa_ss_mar_mat_I                                          float32
# pa_ss_mar_mat_II                                         float32
# pa_ss_mar_mat_III                                        float32
# pa_ss_mar_mat_IV                                         float32
# ind_len                                                  float64
# ind_mat                                                  float64
# ind-compuesto                                            float64
# ind_IV                                                   float64
# ind_gral_len                                             float64
# ind_gral_mat                                             float64
# ind_gral                                                 float64
# dtype: object

# %%
# Nominales de baja cardinalidad
categoricas = ['CLAVE DE LA ENTIDAD', 'NOMBRE_ESCUELA', 'CLAVE_ESCUELA', 'TURNO',
       'EXTENSIÓN', 'ENTIDAD', 'MUNICIPIO', 'LOCALIDAD', 'SUBSISTEMA',
       'GRADO_MARGINACIÓN_LOCALIDAD_CCT', 'SOSTENIMIENTO']
nominal_low_card = ['TURNO','EXTENSIÓN', 'GRADO_MARGINACIÓN_LOCALIDAD_CCT', 'SOSTENIMIENTO']

# %%
planea.SUBSISTEMA.unique()
# Out:
# array(['BACHILLERATO AUTÓNOMO', 'DGETA', 'PARTICULARES',
#        'TELEBACHILLERATOS', 'EMSAD', 'ASOCIACIÓN CIVIL', 'CECYTE',
#        'TELEBACHILLERATOS COMUNITARIO', 'DGETI', 'DGB',
#        'BACH ESTATAL DGE-CGE', 'CONALEP', 'COBACH', 'DGECYTM',
#        'OTRAS FEDERALES', 'OTRAS ESTATALES', 'COLBACH MEX', 'CETI',
#        'EXTRANJERO', 'REVALIDACION', 'PÚBLICO'], dtype=object)

# %%
planea.GRADO_MARGINACIÓN_LOCALIDAD_CCT.unique()
# Out:
# array(['ALTO', 'BAJO', 'MUY BAJO', 'MEDIO', 'MUY ALTO'], dtype=object)

# %%
planea.SOSTENIMIENTO.unique()
# Out:
# array(['AUTÓNOMAS', 'FEDERAL', 'PARTICULARES', 'ESTATAL', 'EXTRANJERO'],
#       dtype=object)

# %%
planea.TURNO.unique()
# Out:
# array(['MATUTINO', 'VESPERTINO', 'NOCTURNO', 'DISCONTINUO'], dtype=object)

# %%
pd.get_dummies?

# %%
planea_dummies =pd.get_dummies(planea[nominal_low_card],drop_first=True)
planea_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12848 entries, 0 to 14653
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   TURNO_MATUTINO                            12848 non-null  uint8
#  1   TURNO_NOCTURNO                            12848 non-null  uint8
#  2   TURNO_VESPERTINO                          12848 non-null  uint8
#  3   EXTENSIÓN_NO                              12848 non-null  uint8
#  4   GRADO_MARGINACIÓN_LOCALIDAD_CCT_BAJO      12848 non-null  uint8
#  5   GRADO_MARGINACIÓN_LOCALIDAD_CCT_MEDIO     12848 non-null  uint8
#  6   GRADO_MARGINACIÓN_LOCALIDAD_CCT_MUY ALTO  12848 non-null  uint8
#  7   GRADO_MARGINACIÓN_LOCALIDAD_CCT_MUY BAJO  12848 non-null  uint8
#  8   SOSTENIMIENTO_ESTATAL                     12848 non-null  uint8
#  9   SOSTENIMIENTO_EXTRANJERO                  12848 non-null  uint8
#  10  SOSTENIMIENTO_FEDERAL                     12848 non-null  uint8
#  11  SOSTENIMIENTO_PARTICULARES                12848 non-null  uint8
# dtypes: uint8(12)
# memory usage: 250.9 KB

# %% [markdown]
# ## Cambiar a tipo category las columnas nominales de tipo object que se necesitan como variables para la analítica
#
# + Las de cardinalidad 1 (son llaves candidas de la relación, no se necesitan convertir)

# %%
for col in nominal_low_card:
    planea[col] = planea[col].astype('category')

# %%
planea.dtypes
# Out:
# CLAVE DE LA ENTIDAD                                         int32
# NOMBRE_ESCUELA                                             object
# CLAVE_ESCUELA                                              object
# TURNO                                                    category
# EXTENSIÓN                                                category
# ENTIDAD                                                    object
# MUNICIPIO                                                  object
# LOCALIDAD                                                  object
# SUBSISTEMA                                                 object
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                          category
# SOSTENIMIENTO                                            category
# ALUMNOS_PROGRAMADOS                                         int32
# ALUMNOS_EVALUADOS                                           int32
# PORCENTAJE_ ALUMNOS_EVALUADOS                             float64
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                         bool
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE       int32
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT             int32
# esc_leng_I                                                float32
# esc_leng_II                                               float32
# esc_leng_III                                              float32
# esc_leng_IV                                               float32
# ent_ss_mar_len_I                                          float32
# ent_ss_mar_len_II                                         float32
# ent_ss_mar_len_III                                        float32
# ent_ss_mar_len_IV                                         float32
# pa_ss_mar_len_I                                           float32
# pa_ss_mar_len_II                                          float32
# pa_ss_mar_len_III                                         float32
# pa_ss_mar_len_IV                                          float32
# esc_mat_I                                                 float32
# esc_mat_II                                                float32
# esc_mat_III                                               float32
# esc_mat_IV                                                float32
# ent_ss_mar_mat_I                                          float32
# ent_ss_mar_mat_II                                         float32
# ent_ss_mar_mat_III                                        float32
# ent_ss_mar_mat_IV                                         float32
# pa_ss_mar_mat_I                                           float32
# pa_ss_mar_mat_II                                          float32
# pa_ss_mar_mat_III                                         float32
# pa_ss_mar_mat_IV                                          float32
# ind_len                                                   float64
# ind_mat                                                   float64
# ind-compuesto                                             float64
# ind_IV                                                    float64
# ind_gral_len                                              float64
# ind_gral_mat                                              float64
# ind_gral                                                  float64
# dtype: object

# %% [markdown]
# ## 5. Guardar archivo de PLANEA 2015 limpio y sus tipos

# %%
# DateFrame con dtypes que no son datetime

tipos = pd.DataFrame(planea.dtypes,columns=['dtypes'])

non_date = tipos[tipos['dtypes'] != 'datetime64[ns]']
non_date
# Out:
#                                                       dtypes
# CLAVE DE LA ENTIDAD                                    int32
# NOMBRE_ESCUELA                                        object
# CLAVE_ESCUELA                                         object
# TURNO                                               category
# EXTENSIÓN                                           category
# ENTIDAD                                               object
# MUNICIPIO                                             object
# LOCALIDAD                                             object
# SUBSISTEMA                                            object
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                     category
# SOSTENIMIENTO                                       category
# ALUMNOS_PROGRAMADOS                                    int32
# ALUMNOS_EVALUADOS                                      int32
# PORCENTAJE_ ALUMNOS_EVALUADOS                        float64
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                    bool
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LE...     int32
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT        int32
# esc_leng_I                                           float32
# esc_leng_II                                          float32
# esc_leng_III                                         float32
# esc_leng_IV                                          float32
# ent_ss_mar_len_I                                     float32
# ent_ss_mar_len_II                                    float32
# ent_ss_mar_len_III                                   float32
# ent_ss_mar_len_IV                                    float32
# pa_ss_mar_len_I                                      float32
# pa_ss_mar_len_II                                     float32
# pa_ss_mar_len_III                                    float32
# pa_ss_mar_len_IV                                     float32
# esc_mat_I                                            float32
# esc_mat_II                                           float32
# esc_mat_III                                          float32
# esc_mat_IV                                           float32
# ent_ss_mar_mat_I                                     float32
# ent_ss_mar_mat_II                                    float32
# ent_ss_mar_mat_III                                   float32
# ent_ss_mar_mat_IV                                    float32
# pa_ss_mar_mat_I                                      float32
# pa_ss_mar_mat_II                                     float32
# pa_ss_mar_mat_III                                    float32
# pa_ss_mar_mat_IV                                     float32
# ind_len                                              float64
# ind_mat                                              float64
# ind-compuesto                                        float64
# ind_IV                                               float64
# ind_gral_len                                         float64
# ind_gral_mat                                         float64
# ind_gral                                             float64

# %%
# Metadatos
# Guardar en archivo los tipos que no son datetime
non_date.to_csv( 'tipos_Planea2015.csv',index_label='columnas',header=['tipos'],encoding='latin1')

# %%
planea.to_csv('Planea2015_Limpio_newFeatures.csv',header=True,index=False,encoding='latin')

# %%
len(planea)
# Out:
# 12848

# %%
planea.isnull().sum()
# Out:
# CLAVE DE LA ENTIDAD                                      0
# NOMBRE_ESCUELA                                           0
# CLAVE_ESCUELA                                            0
# TURNO                                                    0
# EXTENSIÓN                                                0
# ENTIDAD                                                  0
# MUNICIPIO                                                0
# LOCALIDAD                                                0
# SUBSISTEMA                                               0
# GRADO_MARGINACIÓN_LOCALIDAD_CCT                          0
# SOSTENIMIENTO                                            0
# ALUMNOS_PROGRAMADOS                                      0
# ALUMNOS_EVALUADOS                                        0
# PORCENTAJE_ ALUMNOS_EVALUADOS                            0
# ALUMNOS_EVALUADOS_MENOR_80_PORCIENTO                     0
# ALUMNOS_CONTESTARON_ 50_PORCIENTO_O_MÁS_PREG_LENGUAJE    0
# ALUMNOS_CONTESTARON_50_PORCIENTO_O_MÁS_PREG_MAT          0
# esc_leng_I                                               0
# esc_leng_II                                              0
# esc_leng_III                                             0
# esc_leng_IV                                              0
# ent_ss_mar_len_I                                         0
# ent_ss_mar_len_II                                        0
# ent_ss_mar_len_III                                       0
# ent_ss_mar_len_IV                                        0
# pa_ss_mar_len_I                                          0
# pa_ss_mar_len_II                                         0
# pa_ss_mar_len_III                                        0
# pa_ss_mar_len_IV                                         0
# esc_mat_I                                                0
# esc_mat_II                                               0
# esc_mat_III                                              0
# esc_mat_IV                                               0
# ent_ss_mar_mat_I                                         0
# ent_ss_mar_mat_II                                        0
# ent_ss_mar_mat_III                                       0
# ent_ss_mar_mat_IV                                        0
# pa_ss_mar_mat_I                                          0
# pa_ss_mar_mat_II                                         0
# pa_ss_mar_mat_III                                        0
# pa_ss_mar_mat_IV                                         0
# ind_len                                                  0
# ind_mat                                                  0
# ind-compuesto                                            0
# ind_IV                                                   0
# ind_gral_len                                             0
# ind_gral_mat                                             0
# ind_gral                                                 0
# dtype: int64
